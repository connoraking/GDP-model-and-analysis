# %%
import numpy as np
import pandas as pd

# Manually deleted first row of the excel sheet that was messing up the column names
df_edu = pd.read_csv('E:\\Career\\Projects\\Data-Driven GDP Analysis\\data\\education.csv', encoding='ISO-8859-1')

df_edu
# Out:
#       Region/Country/Area                     Unnamed: 1  Year  \
# 0                       1  Total, all countries or areas  2005
# 1                       1  Total, all countries or areas  2005
# 2                       1  Total, all countries or areas  2005
# 3                       1  Total, all countries or areas  2005
# 4                       1  Total, all countries or areas  2005
# ...                   ...                            ...   ...
# 7525                  722                           SIDS  2020
# 7526                  722                           SIDS  2020
# 7527                  722                           SIDS  2020
# 7528                  722                           SIDS  2020
# 7529                  722                           SIDS  2020
#
#                                                  Series    Value  Footnotes  \
# 0     Students enrolled in primary education (thousa...  678,907  Estimate.
# 1               Gross enrollment ratio - Primary (male)    104.5  Estimate.
# 2             Gross enrollment ratio - Primary (female)     99.7        NaN
# 3     Students enrolled in lower secondary education...  309,665        NaN
# 4     Gross enrollment ratio - Lower secondary level...     80.7        NaN
# ...                                                 ...      ...        ...
# 7525  Gross enrollment ratio - Lower secondary level...     76.5  Estimate.
# 7526  Gross enrollment ratio - Lower secondary level...     74.8  Estimate.
# 7527  Students enrolled in upper secondary education...    1,890  Estimate.
# 7528  Gross enrollment ratio - Upper secondary level...     56.1  Estimate.
# 7529  Gross enrollment ratio - Upper secondary level...     59.4  Estimate.
#
#                                                  Source
# 0     United Nations Educational, Scientific and Cul...
# 1     United Nations Educational, Scientific and Cul...
# 2     United Nations Educational, Scientific and Cul...
# 3     United Nations Educational, Scientific and Cul...
# 4     United Nations Educational, Scientific and Cul...
# ...                                                 ...
# 7525  United Nations Educational, Scientific and Cul...
# 7526  United Nations Educational, Scientific and Cul...
# 7527  United Nations Educational, Scientific and Cul...
# 7528  United Nations Educational, Scientific and Cul...
# 7529  United Nations Educational, Scientific and Cul...
#
# [7530 rows x 7 columns]

# %%
# Doing some columns fixes

df_edu = df_edu.drop(columns = ['Footnotes', 'Source', 'Region/Country/Area']).rename(columns = {'Unnamed: 1':'country',
                                                                                                     'Year': 'year'})

df_edu.head()
# Out:
#                          country  year  \
# 0  Total, all countries or areas  2005
# 1  Total, all countries or areas  2005
# 2  Total, all countries or areas  2005
# 3  Total, all countries or areas  2005
# 4  Total, all countries or areas  2005
#
#                                               Series    Value
# 0  Students enrolled in primary education (thousa...  678,907
# 1            Gross enrollment ratio - Primary (male)    104.5
# 2          Gross enrollment ratio - Primary (female)     99.7
# 3  Students enrolled in lower secondary education...  309,665
# 4  Gross enrollment ratio - Lower secondary level...     80.7

# %%
# Removing the region observations, all before Afghanistan

afghan_index = df_edu[df_edu['country'] == 'Afghanistan'].index[0] # first index that matches the condition
df_edu = df_edu.loc[afghan_index: ]

df_edu
# Out:
#           country  year                                             Series  \
# 468   Afghanistan  2005  Students enrolled in primary education (thousa...
# 469   Afghanistan  2005            Gross enrollment ratio - Primary (male)
# 470   Afghanistan  2005          Gross enrollment ratio - Primary (female)
# 471   Afghanistan  2005  Students enrolled in lower secondary education...
# 472   Afghanistan  2005  Gross enrollment ratio - Lower secondary level...
# ...           ...   ...                                                ...
# 7525         SIDS  2020  Gross enrollment ratio - Lower secondary level...
# 7526         SIDS  2020  Gross enrollment ratio - Lower secondary level...
# 7527         SIDS  2020  Students enrolled in upper secondary education...
# 7528         SIDS  2020  Gross enrollment ratio - Upper secondary level...
# 7529         SIDS  2020  Gross enrollment ratio - Upper secondary level...
#
#       Value
# 468   4,319
# 469   123.1
# 470    71.8
# 471     461
# 472    36.9
# ...     ...
# 7525   76.5
# 7526   74.8
# 7527  1,890
# 7528   56.1
# 7529   59.4
#
# [7062 rows x 4 columns]

# %%
# SIDS stands for "Small Island Developing States". We will remove these type of observations for now by removing
# observations after Zimbabwe

zimbab_last_index = df_edu[df_edu['country'] == 'Zimbabwe'].index[-1] #-1 selects the last element from the index array
df_edu = df_edu.loc[:zimbab_last_index] # Pandas slicing using `.loc` is inclusive therefore no need for the + 1

df_edu
# Out:
#           country  year                                             Series  \
# 468   Afghanistan  2005  Students enrolled in primary education (thousa...
# 469   Afghanistan  2005            Gross enrollment ratio - Primary (male)
# 470   Afghanistan  2005          Gross enrollment ratio - Primary (female)
# 471   Afghanistan  2005  Students enrolled in lower secondary education...
# 472   Afghanistan  2005  Gross enrollment ratio - Lower secondary level...
# ...           ...   ...                                                ...
# 7417     Zimbabwe  2015            Gross enrollment ratio - Primary (male)
# 7418     Zimbabwe  2015          Gross enrollment ratio - Primary (female)
# 7419     Zimbabwe  2021  Students enrolled in primary education (thousa...
# 7420     Zimbabwe  2021            Gross enrollment ratio - Primary (male)
# 7421     Zimbabwe  2021          Gross enrollment ratio - Primary (female)
#
#       Value
# 468   4,319
# 469   123.1
# 470    71.8
# 471     461
# 472    36.9
# ...     ...
# 7417  104.9
# 7418  102.8
# 7419  2,899
# 7420   95.9
# 7421   96.4
#
# [6954 rows x 4 columns]

# %%
# Making the `Value` column a numerical double
df_edu = df_edu.copy()

df_edu.loc[:, 'Value'] = df_edu['Value'].str.replace(',', '').astype(float)
df_edu.dtypes
# Out:
# country     object
# year         int64
# Series      object
# Value      float64
# dtype: object

# %%
# Checking NAs

df_edu.isna().sum()
# Out:
# country    0
# year       0
# Series     0
# Value      0
# dtype: int64

# %% [markdown]
# ## Pivoting the `Series` column

# %%
df_edu['Series'].unique()
# Out:
# array(['Students enrolled in primary education (thousands)',
#        'Gross enrollment ratio - Primary (male)',
#        'Gross enrollment ratio - Primary (female)',
#        'Students enrolled in lower secondary education (thousands)',
#        'Gross enrollment ratio - Lower secondary level (male)',
#        'Gross enrollment ratio - Lower secondary level (female)',
#        'Students enrolled in upper secondary education (thousands)',
#        'Gross enrollment ratio - Upper secondary level (male)',
#        'Gross enrollment ratio - Upper secondary level (female)'],
#       dtype=object)

# %%
# Renaming to prepare for columns

df_edu['Series'].replace({
    'Students enrolled in primary education (thousands)':           'primary_total_enrolled',
    'Gross enrollment ratio - Primary (male)':                      'primary_enrollment_ratio_male',
    'Gross enrollment ratio - Primary (female)':                    'primary_enrollment_ratio_female',
    'Students enrolled in lower secondary education (thousands)':   'lower_secondary_total_enrolled',
    'Gross enrollment ratio - Lower secondary level (male)':        'lower_secondary_enrollment_ratio_male',
    'Gross enrollment ratio - Lower secondary level (female)':      'lower_secondary_enrollment_ratio_female',
    'Students enrolled in upper secondary education (thousands)':   'upper_secondary_total_enrolled',
    'Gross enrollment ratio - Upper secondary level (male)':        'upper_secondary_enrollment_ratio_male',
    'Gross enrollment ratio - Upper secondary level (female)':      'upper_secondary_enrollment_ratio_female'
},
    inplace = True)

df_edu
# Out:
#           country  year                                 Series   Value
# 468   Afghanistan  2005                 primary_total_enrolled  4319.0
# 469   Afghanistan  2005          primary_enrollment_ratio_male   123.1
# 470   Afghanistan  2005        primary_enrollment_ratio_female    71.8
# 471   Afghanistan  2005         lower_secondary_total_enrolled   461.0
# 472   Afghanistan  2005  lower_secondary_enrollment_ratio_male    36.9
# ...           ...   ...                                    ...     ...
# 7417     Zimbabwe  2015          primary_enrollment_ratio_male   104.9
# 7418     Zimbabwe  2015        primary_enrollment_ratio_female   102.8
# 7419     Zimbabwe  2021                 primary_total_enrolled  2899.0
# 7420     Zimbabwe  2021          primary_enrollment_ratio_male    95.9
# 7421     Zimbabwe  2021        primary_enrollment_ratio_female    96.4
#
# [6954 rows x 4 columns]

# %%
# Pivoting, 

df_pivot = df_edu.pivot_table(index = ['country', 'year'], columns = 'Series', values = 'Value', aggfunc = 'first').reset_index()

df_edu = df_pivot

# Numbers were by thousands thus multiplying by thousand to get actual amount
df_edu['primary_total_enrolled'] = df_edu['primary_total_enrolled'] * 1000 
df_edu['lower_secondary_total_enrolled'] = df_edu['primary_total_enrolled'] * 1000 
df_edu['upper_secondary_total_enrolled'] = df_edu['primary_total_enrolled'] * 1000 

df_edu['primary_total_enrolled'] = df_edu['primary_total_enrolled'].astype(int)

df_edu
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-d44b93818a4c> in <module>
#      10 df_edu['upper_secondary_total_enrolled'] = df_edu['primary_total_enrolled'] * 1000
#      11
# ---> 12 df_edu['primary_total_enrolled'] = df_edu['primary_total_enrolled'].astype(int)
#      13
#      14 df_edu
#
# c:\users\connor\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\users\connor\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# c:\users\connor\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# c:\users\connor\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# c:\users\connor\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     866
#     867         if not np.isfinite(arr).all():
# --> 868             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     869
#     870     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# ## Adding continent column

# %%
# Same methodology when cleaning the gdp data

import pycountry_convert as pc

def get_continent(country_name):
    try:
        # Make sure country_name is a string, not a Series or DataFrame
        assert isinstance(country_name, str), f"Input must be str, got {type(country_name)}"
        
        country_code = pc.country_name_to_country_alpha2(country_name)
        continent_code = pc.country_alpha2_to_continent_code(country_code)
        continent_name = pc.convert_continent_code_to_continent_name(continent_code)
        return continent_name
    except Exception as e:
        print(f"Error processing country: {country_name} - {e}")
        # Return None or you could specify a default value, e.g., 'Unknown'
        return None

# Apply get_continent function row-wise using apply with axis=1
df_test = df_edu.copy()
df_test['continent'] = df_edu['country'].apply(get_continent)
df_test
# Out:
# Error processing country: Bolivia (Plurin. State of) - "Invalid Country Name: 'Bolivia (Plurin. State of)'"
# Error processing country: Bolivia (Plurin. State of) - "Invalid Country Name: 'Bolivia (Plurin. State of)'"
# Error processing country: Bolivia (Plurin. State of) - "Invalid Country Name: 'Bolivia (Plurin. State of)'"
# Error processing country: Bolivia (Plurin. State of) - "Invalid Country Name: 'Bolivia (Plurin. State of)'"
# Error processing country: China, Hong Kong SAR - "Invalid Country Name: 'China, Hong Kong SAR'"
# Error processing country: China, Hong Kong SAR - "Invalid Country Name: 'China, Hong Kong SAR'"
# Error processing country: China, Hong Kong SAR - "Invalid Country Name: 'China, Hong Kong SAR'"
# Error processing country: China, Hong Kong SAR - "Invalid Country Name: 'China, Hong Kong SAR'"
# Error processing country: China, Macao SAR - "Invalid Country Name: 'China, Macao SAR'"
# Error processing country: China, Macao SAR - "Invalid Country Name: 'China, Macao SAR'"
# Error processing country: China, Macao SAR - "Invalid Country Name: 'China, Macao SAR'"
# Error processing country: China, Macao SAR - "Invalid Country Name: 'China, Macao SAR'"
# Error processing country: Côte dIvoire - "Invalid Country Name: 'Côte d\x92Ivoire'"
# Error processing country: Côte dIvoire - "Invalid Country Name: 'Côte d\x92Ivoire'"
# Error processing country: Côte dIvoire - "Invalid Country Name: 'Côte d\x92Ivoire'"
# Error processing country: Côte dIvoire - "Invalid Country Name: 'Côte d\x92Ivoire'"
# Error processing country: Dem. People's Rep. Korea - "Invalid Country Name: 'Dem. People's Rep. Korea'"
# Error processing country: Dem. People's Rep. Korea - "Invalid Country Name: 'Dem. People's Rep. Korea'"
# Error processing country: Dem. People's Rep. Korea - "Invalid Country Name: 'Dem. People's Rep. Korea'"
# Error processing country: Dem. Rep. of the Congo - "Invalid Country Name: 'Dem. Rep. of the Congo'"
# Error processing country: Dem. Rep. of the Congo - "Invalid Country Name: 'Dem. Rep. of the Congo'"
# Error processing country: Dem. Rep. of the Congo - "Invalid Country Name: 'Dem. Rep. of the Congo'"
# Error processing country: Iran (Islamic Republic of) - "Invalid Country Name: 'Iran (Islamic Republic of)'"
# Error processing country: Iran (Islamic Republic of) - "Invalid Country Name: 'Iran (Islamic Republic of)'"
# Error processing country: Iran (Islamic Republic of) - "Invalid Country Name: 'Iran (Islamic Republic of)'"
# Error processing country: Iran (Islamic Republic of) - "Invalid Country Name: 'Iran (Islamic Republic of)'"
# Error processing country: Iran (Islamic Republic of) - "Invalid Country Name: 'Iran (Islamic Republic of)'"
# Error processing country: Lao People's Dem. Rep. - "Invalid Country Name: 'Lao People's Dem. Rep.'"
# Error processing country: Lao People's Dem. Rep. - "Invalid Country Name: 'Lao People's Dem. Rep.'"
# Error processing country: Lao People's Dem. Rep. - "Invalid Country Name: 'Lao People's Dem. Rep.'"
# Error processing country: Lao People's Dem. Rep. - "Invalid Country Name: 'Lao People's Dem. Rep.'"
# Error processing country: Micronesia (Fed. States of) - "Invalid Country Name: 'Micronesia (Fed. States of)'"
# Error processing country: Micronesia (Fed. States of) - "Invalid Country Name: 'Micronesia (Fed. States of)'"
# Error processing country: Micronesia (Fed. States of) - "Invalid Country Name: 'Micronesia (Fed. States of)'"
# Error processing country: Micronesia (Fed. States of) - "Invalid Country Name: 'Micronesia (Fed. States of)'"
# Error processing country: Netherlands (Kingdom of the) - "Invalid Country Name: 'Netherlands (Kingdom of the)'"
# Error processing country: Netherlands (Kingdom of the) - "Invalid Country Name: 'Netherlands (Kingdom of the)'"
# Error processing country: Netherlands (Kingdom of the) - "Invalid Country Name: 'Netherlands (Kingdom of the)'"
# Error processing country: Netherlands (Kingdom of the) - "Invalid Country Name: 'Netherlands (Kingdom of the)'"
# Error processing country: Republic of Korea - "Invalid Country Name: 'Republic of Korea'"
# Error processing country: Republic of Korea - "Invalid Country Name: 'Republic of Korea'"
# Error processing country: Republic of Korea - "Invalid Country Name: 'Republic of Korea'"
# Error processing country: Republic of Korea - "Invalid Country Name: 'Republic of Korea'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Sint Maarten (Dutch part) - "Invalid Country Alpha-2 code: 'SX'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: Sudan [former] - "Invalid Country Name: 'Sudan [former]'"
# Error processing country: Sudan [former] - "Invalid Country Name: 'Sudan [former]'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: United Rep. of Tanzania - "Invalid Country Name: 'United Rep. of Tanzania'"
# Error processing country: United Rep. of Tanzania - "Invalid Country Name: 'United Rep. of Tanzania'"
# Error processing country: United Rep. of Tanzania - "Invalid Country Name: 'United Rep. of Tanzania'"
# Error processing country: United Rep. of Tanzania - "Invalid Country Name: 'United Rep. of Tanzania'"
# Error processing country: Venezuela (Boliv. Rep. of) - "Invalid Country Name: 'Venezuela (Boliv. Rep. of)'"
# Error processing country: Venezuela (Boliv. Rep. of) - "Invalid Country Name: 'Venezuela (Boliv. Rep. of)'"
# Error processing country: Venezuela (Boliv. Rep. of) - "Invalid Country Name: 'Venezuela (Boliv. Rep. of)'"
# Error processing country: Venezuela (Boliv. Rep. of) - "Invalid Country Name: 'Venezuela (Boliv. Rep. of)'"
# Series      country  year  lower_secondary_enrollment_ratio_female  \
# 0       Afghanistan  2005                                     12.7
# 1       Afghanistan  2010                                     46.4
# 2       Afghanistan  2015                                     45.5
# 3       Afghanistan  2018                                     50.6
# 4       Afghanistan  2019                                     52.2
# ..              ...   ...                                      ...
# 900          Zambia  2017                                     59.8
# 901        Zimbabwe  2003                                     57.3
# 902        Zimbabwe  2013                                     75.2
# 903        Zimbabwe  2015                                      NaN
# 904        Zimbabwe  2021                                      NaN
#
# Series  lower_secondary_enrollment_ratio_male  \
# 0                                        36.9
# 1                                        87.4
# 2                                        77.9
# 3                                        86.3
# 4                                        87.6
# ..                                        ...
# 900                                      61.7
# 901                                      61.4
# 902                                      72.8
# 903                                       NaN
# 904                                       NaN
#
# Series  lower_secondary_total_enrolled_thousands  \
# 0                                          461.0
# 1                                         1477.0
# 2                                         1669.0
# 3                                         1983.0
# 4                                         2067.0
# ..                                           ...
# 900                                        511.0
# 901                                        387.0
# 902                                        467.0
# 903                                          NaN
# 904                                          NaN
#
# Series  primary_enrollment_ratio_female  primary_enrollment_ratio_male  \
# 0                                  71.8                          123.1
# 1                                  80.6                          118.6
# 2                                  83.5                          122.7
# 3                                  82.9                          124.2
# 4                                  85.4                          127.1
# ..                                  ...                            ...
# 900                                99.9                           97.5
# 901                                 NaN                            NaN
# 902                               108.7                          111.1
# 903                               102.8                          104.9
# 904                                96.4                           95.9
#
# Series  primary_total_enrolled_thousands  \
# 0                                 4319.0
# 1                                 5279.0
# 2                                 6199.0
# 3                                 6545.0
# 4                                 6778.0
# ..                                   ...
# 900                               3285.0
# 901                                  NaN
# 902                               2663.0
# 903                               2658.0
# 904                               2899.0
#
# Series  upper_secondary_enrollment_ratio_female  \
# 0                                           4.9
# 1                                          17.8
# 2                                          27.1
# 3                                          28.5
# 4                                           NaN
# ..                                          ...
# 900                                         NaN
# 901                                         NaN
# 902                                        38.9
# 903                                         NaN
# 904                                         NaN
#
# Series  upper_secondary_enrollment_ratio_male  \
# 0                                        17.5
# 1                                        42.7
# 2                                        52.6
# 3                                        52.4
# 4                                         NaN
# ..                                        ...
# 900                                       NaN
# 901                                       NaN
# 902                                      43.2
# 903                                       NaN
# 904                                       NaN
#
# Series  upper_secondary_total_enrolled_thousands continent
# 0                                          190.0      Asia
# 1                                          567.0      Asia
# 2                                          982.0      Asia
# 3                                         1081.0      Asia
# 4                                            NaN      Asia
# ..                                           ...       ...
# 900                                          NaN    Africa
# 901                                          NaN    Africa
# 902                                        491.0    Africa
# 903                                          NaN    Africa
# 904                                          NaN    Africa
#
# [905 rows x 12 columns]

# %%
# Renaming and Removing Countries

df_edu['country'] = df_edu['country'].replace('Bolivia (Plurin. State of)', 'Bolivia')
df_edu['country'] = df_edu['country'].replace('China, Hong Kong SAR', 'Hong Kong')
df_edu['country'] = df_edu['country'].replace('China, Macao SAR', 'Macao')
df_edu['country'] = df_edu['country'].replace('Côte d\x92Ivoire', 'Ivory Coast')
df_edu['country'] = df_edu['country'].replace("Dem. People's Rep. Korea", 'North Korea')
df_edu['country'] = df_edu['country'].replace("Dem. Rep. of the Congo", 'Democratic Republic of the Congo')
df_edu['country'] = df_edu['country'].replace('Iran (Islamic Republic of)', 'Iran')
df_edu['country'] = df_edu['country'].replace('Micronesia (Fed. States of)', 'Micronesia')
df_edu['country'] = df_edu['country'].replace('Netherlands (Kingdom of the)', 'Netherlands')
df_edu['country'] = df_edu['country'].replace('Republic of Korea', 'South Korea')
df_edu['country'] = df_edu['country'].replace('United Rep. of Tanzania', 'Tanzania')
df_edu['country'] = df_edu['country'].replace('Venezuela (Boliv. Rep. of)', 'Venezuela')

# %%
countries_to_remove = ["Lao People's Dem. Rep.", 'Netherlands Antilles [former]', 'Sint Maarten (Dutch part)']
df_removal = df_edu[~df_edu['country'].isin(countries_to_remove)]

df_test = df_removal.copy() # Pandas gets mad when you don't make it explicitly clear that it's a copy
df_test['continent'] = df_test['country'].apply(get_continent)
# Out:
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: Saint Vincent & Grenadines - "Invalid Country Name: 'Saint Vincent & Grenadines'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: State of Palestine - "Invalid Country Name: 'State of Palestine'"
# Error processing country: Sudan [former] - "Invalid Country Name: 'Sudan [former]'"
# Error processing country: Sudan [former] - "Invalid Country Name: 'Sudan [former]'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"
# Error processing country: Timor-Leste - "Invalid Country Alpha-2 code: 'TL'"

# %%
# Inserting continent for some countries manually
df_test.loc[df_test['country'] == 'State of Palestine', 'continent'] = 'Africa'
df_test.loc[df_test['country'] == 'Kosovo', 'continent'] = 'Europe'
df_test.loc[df_test['country'] == 'Timor-Leste', 'continent'] = 'Asia'
df_test.loc[df_test['country'] == 'Saint Vincent & Grenadines', 'continent'] = 'North America'
df_test.loc[df_test['country'] == 'Zanzibar', 'continent'] = 'Africa'

# Replacing 'Sudan [former]' with Sudan before 2010
df_test.loc[(df_test['country'] == 'Sudan [former]') & (df_test['year'] < 2010), 'country'] = 'Sudan' 
df_test = df_test[df_test['country'] != 'Sudan [former]']
df_test.loc[df_test['country'] == 'Sudan', 'continent'] = 'Africa'

# %%
df_test
# Out:
# Series      country  year  lower_secondary_enrollment_ratio_female  \
# 0       Afghanistan  2005                                     12.7
# 1       Afghanistan  2010                                     46.4
# 2       Afghanistan  2015                                     45.5
# 3       Afghanistan  2018                                     50.6
# 4       Afghanistan  2019                                     52.2
# ..              ...   ...                                      ...
# 900          Zambia  2017                                     59.8
# 901        Zimbabwe  2003                                     57.3
# 902        Zimbabwe  2013                                     75.2
# 903        Zimbabwe  2015                                      NaN
# 904        Zimbabwe  2021                                      NaN
#
# Series  lower_secondary_enrollment_ratio_male  \
# 0                                        36.9
# 1                                        87.4
# 2                                        77.9
# 3                                        86.3
# 4                                        87.6
# ..                                        ...
# 900                                      61.7
# 901                                      61.4
# 902                                      72.8
# 903                                       NaN
# 904                                       NaN
#
# Series  lower_secondary_total_enrolled_thousands  \
# 0                                          461.0
# 1                                         1477.0
# 2                                         1669.0
# 3                                         1983.0
# 4                                         2067.0
# ..                                           ...
# 900                                        511.0
# 901                                        387.0
# 902                                        467.0
# 903                                          NaN
# 904                                          NaN
#
# Series  primary_enrollment_ratio_female  primary_enrollment_ratio_male  \
# 0                                  71.8                          123.1
# 1                                  80.6                          118.6
# 2                                  83.5                          122.7
# 3                                  82.9                          124.2
# 4                                  85.4                          127.1
# ..                                  ...                            ...
# 900                                99.9                           97.5
# 901                                 NaN                            NaN
# 902                               108.7                          111.1
# 903                               102.8                          104.9
# 904                                96.4                           95.9
#
# Series  primary_total_enrolled_thousands  \
# 0                                 4319.0
# 1                                 5279.0
# 2                                 6199.0
# 3                                 6545.0
# 4                                 6778.0
# ..                                   ...
# 900                               3285.0
# 901                                  NaN
# 902                               2663.0
# 903                               2658.0
# 904                               2899.0
#
# Series  upper_secondary_enrollment_ratio_female  \
# 0                                           4.9
# 1                                          17.8
# 2                                          27.1
# 3                                          28.5
# 4                                           NaN
# ..                                          ...
# 900                                         NaN
# 901                                         NaN
# 902                                        38.9
# 903                                         NaN
# 904                                         NaN
#
# Series  upper_secondary_enrollment_ratio_male  \
# 0                                        17.5
# 1                                        42.7
# 2                                        52.6
# 3                                        52.4
# 4                                         NaN
# ..                                        ...
# 900                                       NaN
# 901                                       NaN
# 902                                      43.2
# 903                                       NaN
# 904                                       NaN
#
# Series  upper_secondary_total_enrolled_thousands continent
# 0                                          190.0      Asia
# 1                                          567.0      Asia
# 2                                          982.0      Asia
# 3                                         1081.0      Asia
# 4                                            NaN      Asia
# ..                                           ...       ...
# 900                                          NaN    Africa
# 901                                          NaN    Africa
# 902                                        491.0    Africa
# 903                                          NaN    Africa
# 904                                          NaN    Africa
#
# [900 rows x 12 columns]

# %%
# Male divided by female
# So values greater than 1 indicate there are more boys in school than girls and less than 1 suggests more girls than boys

df_test['lower_secondary_enrollment_ratio'] = df_test['lower_secondary_enrollment_ratio_male'] / df_test['lower_secondary_enrollment_ratio_female']
df_test['upper_secondary_enrollment_ratio'] = df_test['upper_secondary_enrollment_ratio_male'] / df_test['upper_secondary_enrollment_ratio_female']
df_test['primary_enrollment_ratio'] = df_test['primary_enrollment_ratio_male'] / df_test['primary_enrollment_ratio_female']
df_test = df_test.drop(columns = ['lower_secondary_enrollment_ratio_male', 'lower_secondary_enrollment_ratio_female',
                                 'upper_secondary_enrollment_ratio_male', 'upper_secondary_enrollment_ratio_female',
                                 'primary_enrollment_ratio_male', 'primary_enrollment_ratio_female'])
df_test['total_enrolled'] = df_test['lower_secondary_total_enrolled_thousands', ]
df_test
# Out:
# Series      country  year  lower_secondary_total_enrolled_thousands  \
# 0       Afghanistan  2005                                     461.0
# 1       Afghanistan  2010                                    1477.0
# 2       Afghanistan  2015                                    1669.0
# 3       Afghanistan  2018                                    1983.0
# 4       Afghanistan  2019                                    2067.0
# ..              ...   ...                                       ...
# 900          Zambia  2017                                     511.0
# 901        Zimbabwe  2003                                     387.0
# 902        Zimbabwe  2013                                     467.0
# 903        Zimbabwe  2015                                       NaN
# 904        Zimbabwe  2021                                       NaN
#
# Series  primary_total_enrolled_thousands  \
# 0                                 4319.0
# 1                                 5279.0
# 2                                 6199.0
# 3                                 6545.0
# 4                                 6778.0
# ..                                   ...
# 900                               3285.0
# 901                                  NaN
# 902                               2663.0
# 903                               2658.0
# 904                               2899.0
#
# Series  upper_secondary_total_enrolled_thousands continent  \
# 0                                          190.0      Asia
# 1                                          567.0      Asia
# 2                                          982.0      Asia
# 3                                         1081.0      Asia
# 4                                            NaN      Asia
# ..                                           ...       ...
# 900                                          NaN    Africa
# 901                                          NaN    Africa
# 902                                        491.0    Africa
# 903                                          NaN    Africa
# 904                                          NaN    Africa
#
# Series  lower_secondary_enrollment_ratio  upper_secondary_enrollment_ratio  \
# 0                               2.905512                          3.571429
# 1                               1.883621                          2.398876
# 2                               1.712088                          1.940959
# 3                               1.705534                          1.838596
# 4                               1.678161                               NaN
# ..                                   ...                               ...
# 900                             1.031773                               NaN
# 901                             1.071553                               NaN
# 902                             0.968085                          1.110540
# 903                                  NaN                               NaN
# 904                                  NaN                               NaN
#
# Series  primary_enrollment_ratio
# 0                       1.714485
# 1                       1.471464
# 2                       1.469461
# 3                       1.498191
# 4                       1.488290
# ..                           ...
# 900                     0.975976
# 901                          NaN
# 902                     1.022079
# 903                     1.020428
# 904                     0.994813
#
# [900 rows x 9 columns]

# %%
df_test.loc[df_test['country'] == 'United States of America']
# Out:
# Series                   country  year  \
# 868     United States of America  2005
# 869     United States of America  2015
# 870     United States of America  2020
#
# Series  lower_secondary_total_enrolled_thousands  \
# 868                                          NaN
# 869                                      12549.0
# 870                                      12935.0
#
# Series  primary_total_enrolled_thousands  \
# 868                                  NaN
# 869                              24786.0
# 870                              24466.0
#
# Series  upper_secondary_total_enrolled_thousands      continent  \
# 868                                          NaN  North America
# 869                                      11868.0  North America
# 870                                      12248.0  North America
#
# Series  lower_secondary_enrollment_ratio  upper_secondary_enrollment_ratio  \
# 868                             1.016000                          0.944384
# 869                             0.997021                          0.982218
# 870                             1.023599                          1.019567
#
# Series  primary_enrollment_ratio
# 868                     1.010859
# 869                     1.000000
# 870                     1.003996

# %%
# Making continent next to country

column_order = ['country', 'continent'] + [col for col in df_test.columns if col != 'country' and col != 'continent']
df_test = df_test[column_order]
df_test
# Out:
# Series      country continent  year  lower_secondary_enrollment_ratio_female  \
# 0       Afghanistan      Asia  2005                                    0.127
# 1       Afghanistan      Asia  2010                                    0.464
# 2       Afghanistan      Asia  2015                                    0.455
# 3       Afghanistan      Asia  2018                                    0.506
# 4       Afghanistan      Asia  2019                                    0.522
# ..              ...       ...   ...                                      ...
# 900          Zambia    Africa  2017                                    0.598
# 901        Zimbabwe    Africa  2003                                    0.573
# 902        Zimbabwe    Africa  2013                                    0.752
# 903        Zimbabwe    Africa  2015                                      NaN
# 904        Zimbabwe    Africa  2021                                      NaN
#
# Series  lower_secondary_enrollment_ratio_male  \
# 0                                       0.369
# 1                                       0.874
# 2                                       0.779
# 3                                       0.863
# 4                                       0.876
# ..                                        ...
# 900                                     0.617
# 901                                     0.614
# 902                                     0.728
# 903                                       NaN
# 904                                       NaN
#
# Series  lower_secondary_total_enrolled_thousands  \
# 0                                          461.0
# 1                                         1477.0
# 2                                         1669.0
# 3                                         1983.0
# 4                                         2067.0
# ..                                           ...
# 900                                        511.0
# 901                                        387.0
# 902                                        467.0
# 903                                          NaN
# 904                                          NaN
#
# Series  primary_enrollment_ratio_female  primary_enrollment_ratio_male  \
# 0                                 0.718                          1.231
# 1                                 0.806                          1.186
# 2                                 0.835                          1.227
# 3                                 0.829                          1.242
# 4                                 0.854                          1.271
# ..                                  ...                            ...
# 900                               0.999                          0.975
# 901                                 NaN                            NaN
# 902                               1.087                          1.111
# 903                               1.028                          1.049
# 904                               0.964                          0.959
#
# Series  primary_total_enrolled_thousands  \
# 0                                 4319.0
# 1                                 5279.0
# 2                                 6199.0
# 3                                 6545.0
# 4                                 6778.0
# ..                                   ...
# 900                               3285.0
# 901                                  NaN
# 902                               2663.0
# 903                               2658.0
# 904                               2899.0
#
# Series  upper_secondary_enrollment_ratio_female  \
# 0                                         0.049
# 1                                         0.178
# 2                                         0.271
# 3                                         0.285
# 4                                           NaN
# ..                                          ...
# 900                                         NaN
# 901                                         NaN
# 902                                       0.389
# 903                                         NaN
# 904                                         NaN
#
# Series  upper_secondary_enrollment_ratio_male  \
# 0                                       0.175
# 1                                       0.427
# 2                                       0.526
# 3                                       0.524
# 4                                         NaN
# ..                                        ...
# 900                                       NaN
# 901                                       NaN
# 902                                     0.432
# 903                                       NaN
# 904                                       NaN
#
# Series  upper_secondary_total_enrolled_thousands
# 0                                          190.0
# 1                                          567.0
# 2                                          982.0
# 3                                         1081.0
# 4                                            NaN
# ..                                           ...
# 900                                          NaN
# 901                                          NaN
# 902                                        491.0
# 903                                          NaN
# 904                                          NaN
#
# [900 rows x 12 columns]

# %%
df_test.dtypes
# Out:
# Series
# country                                      object
# continent                                    object
# year                                          int64
# lower_secondary_enrollment_ratio_female     float64
# lower_secondary_enrollment_ratio_male       float64
# lower_secondary_total_enrolled_thousands    float64
# primary_enrollment_ratio_female             float64
# primary_enrollment_ratio_male               float64
# primary_total_enrolled_thousands            float64
# upper_secondary_enrollment_ratio_female     float64
# upper_secondary_enrollment_ratio_male       float64
# upper_secondary_total_enrolled_thousands    float64
# dtype: object

# %%
df_edu_clean = df_test.copy()

# Creating csv and hierarchical excel file

df_edu_clean.to_csv('E:\\Career\\Projects\\Data-Driven GDP Analysis\\dataframes\\education_df.csv', index = False)

df_edu_hier = df_edu_clean.sort_values(by = ['continent', 'country']).set_index(['continent', 'country', 'year'])
df_edu_hier.to_excel('E:\\Career\\Projects\\Data-Driven GDP Analysis\\dataframes\\education_df_hierarchical.xlsx', index = True)

# %%
# need to fix more stuff with the ratios because some ratios are over 1 and need to add
